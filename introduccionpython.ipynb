# %% [markdown]
# # **Introduction to Python for Machine Learning**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/BengaluruHouseData/BengaluruHouseData.csv
# /kaggle/input/echocardiogram4/echocardiogram.names
# /kaggle/input/echocardiogram4/echocardiogram.data

# %% [markdown]
# ## (a) Create an array of 10 random integers between 1 and 100, and then calculate the mean and standard deviation of the array.

# %%
matriz = np.random.randint(1, 101, size=10)

# Calcular la media del array
#media = np.mean(matriz)
media2 = matriz.mean()

# Calcular la desviación estándar del array
#desviacion_estandar = np.std(matriz)
desviacion_estandar2 = matriz.std()
#Imprimir el tipo de objeto
print(type(matriz))
# Imprimir el array, la media y la desviación estándar

print("Matriz:", matriz)
#print("Media:", media)
print("Media:", media2)
#print("Desviación estándar:", desviacion_estandar)
print("Desviación estándar:", desviacion_estandar2)
# Out:
# <class 'numpy.ndarray'>
# Matriz: [17  6 48 21 37 60 48 54 94 95]
# Media: 48.0
# Desviación estándar: 28.42534080710379

# %% [markdown]
# ## (b) Create a 2-dimensional array of 3 rows and 4 columns with random integer values. Then, calculate the sum of each row and column.

# %%
# Crear la matriz aleatoria
matriz = np.random.randint(1, 10, size=(3, 4))
print("Matriz:")
print(matriz)

# Calcular la suma de cada fila
suma_filas = np.sum(matriz, axis=1)
print("Suma de cada fila:", suma_filas)
#print()

# Calcular la suma de cada columna
suma_columnas = np.sum(matriz, axis=0)
print("Suma de cada columna:", suma_columnas)
# Out:
# Matriz:
# [[9 3 2 3]
#  [9 8 2 4]
#  [7 2 1 1]]
# Suma de cada fila: [17 23 11]
# Suma de cada columna: [25 13  5  8]

# %% [markdown]
# ## (c) Create a DataFrame with 3 columns: "Name", "Age", and "City". Add at least 5 rows of data to the DataFrame. Then, filter the DataFrame to only include rows where the person's age is greater than or equal to 30.

# %%
import pandas as pd

# Crear el DataFrame
data = {
    'Nombre': ['Made', 'Danny', 'Saul', 'Adhisson', 'Luis'],
    'Edad': [26, 22, 21, 20, 24],
    'Ciudad': ['Santo Domingo', 'Quito', 'Cuenca', 'Guayaquil', 'Ibarra']
}

df = pd.DataFrame(data)

# Filtrar el DataFrame
df_filtrado = df[df['Edad'] >= 30]

# Imprimir el DataFrame filtrado
print(df_filtrado)
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Ciudad]
# Index: []

# %% [markdown]
# ## (d)Load a CSV file into a DataFrame and then calculate the mean, median, and mode of one of the columns in the DataFrame

# %%
# Carga el archivo CSV en un DataFrame
dataframe = pd.read_csv('/kaggle/input/BengaluruHouseData/BengaluruHouseData.csv')

ultima_columna = dataframe.columns[-1]

# Calcula la media de la última columna
media = dataframe[ultima_columna].mean()

# Calcula la mediana de la última columna
mediana = dataframe[ultima_columna].median()

# Calcula la moda de la última columna
moda = dataframe[ultima_columna].mode()[0]

# Imprime los resultados
print("Media:", media)
print("Mediana:", mediana)
print("Moda:", moda)
df.isnull().sum()
# Out:
# Media: 112.49345506042296
# Mediana: 72.0
# Moda: 75.0
# area_type          0
# availability      80
# location          81
# size              96
# society         5502
# total_sqft        80
# bath             153
# balcony          685
# price             80
# dtype: int64

# %% [markdown]
# ## (e) Create a scatter plot of random x and y values between 1 and 100

# %%
# Genera valores aleatorios de x e y
x = np.random.randint(1, 101, size=100)
y = np.random.randint(1, 101, size=100)

# Crea el diagrama de dispersión
plt.scatter(x, y)

# Agrega etiquetas y título al gráfico
plt.xlabel('Valores de x')
plt.ylabel('Valores de y')
plt.title('Diagrama de Dispersión')

# Muestra el gráfico
plt.show()

# %% [markdown]
# ## (f) Load a CSV file into a DataFrame and then create a line chart of one of the columns in the DataFrame.

# %%
# Carga el archivo CSV en un DataFrame
dataframe = pd.read_csv('/kaggle/input/BengaluruHouseData/BengaluruHouseData.csv')

# Elige la columna para el gráfico de líneas
columna = 'price'

# Crea el gráfico de líneas
plt.plot(dataframe[columna])

# Agrega etiquetas y título al gráfico
plt.xlabel('Índice')
plt.ylabel(columna)
plt.title('Gráfico de Líneas')

# Muestra el gráfico
plt.show()

# %% [markdown]
# ## 3. Data Import
# The Echocardiogram data set in the UCI Machine Learning repository contains information on a set of
# patients that suffered heart attacks at some point in the past.

# %% [markdown]
# ### (a) Download the Echocardiogram data set and import it to a data frame. Read the information on the data set and find out how missing values are represented and make sure that they are properly represented.

# %%
dataframe = pd.read_csv('/kaggle/input/echocardiogram4/echocardiogram.data', delimiter=',', error_bad_lines=False)
dataframe
dataframe.replace('?', float('NaN'), inplace=True)
dataframe
# Out:
# /tmp/ipykernel_34/3749355602.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dataframe = pd.read_csv('/kaggle/input/echocardiogram4/echocardiogram.data', delimiter=',', error_bad_lines=False)
# Skipping line 50: expected 13 fields, saw 14
#       11  0  71  0.1  0.260       9  4.600    14      1    1.1  name  1.2  0.2
# 0     19  0  72    0  0.380       6  4.100    14  1.700  0.588  name    1    0
# 1     16  0  55    0  0.260       4  3.420    14      1      1  name    1    0
# 2     57  0  60    0  0.253  12.062  4.603    16  1.450  0.788  name    1    0
# 3     19  1  57    0  0.160      22  5.750    18  2.250  0.571  name    1    0
# 4     26  0  68    0  0.260       5  4.310    12      1  0.857  name    1    0
# ..   ... ..  ..  ...    ...     ...    ...   ...    ...    ...   ...  ...  ...
# 125  7.5  1  64    0   0.24    12.9   4.72    12      1  0.857  name  NaN  NaN
# ...

# %% [markdown]
# los valores faltantes están representados por el signo "?" en las últimas dos columnas. Los valores faltantes se representarán correctamente como NaN "Not a Number" en el DataFrame.

# %% [markdown]
# ### (b) Assign the attributes with meaningful names. You can look for this information on the same webpage.

# %%
##dt = pd.read_csv('/kaggle/input/echocardiogram4/echocardiogram.names', delimiter=',', error_bad_lines=False)
#dt
file_path = '/kaggle/input/echocardiogram4/echocardiogram.names'

with open(file_path, 'r') as file:
    content = file.read()

print(content)
# Out:
# 1. Title: Echocardiogram Data
#
# 2. Source Information:
#    -- Donor: Steven Salzberg (salzberg@cs.jhu.edu)
#    -- Collector:
#       -- Dr. Evlin Kinney
#       -- The Reed Institute
#       -- P.O. Box 402603
#       -- Maimi, FL 33140-0603
#    -- Date Received: 28 February 1989
#
# 3. Past Usage:
#    -- 1. Salzberg, S. (1988).  Exemplar-based learning: Theory and
#          implementation (Technical Report TR-10-88).  Harvard University,
#          Center for Research in Computing Technology, Aiken Computation
#          Laboratory (33 Oxford Street; Cambridge, MA 02138).
#       -- Steve applied his EACH program to predict survival (i.e., life
#          or death), did not use the wall-motion attribute, and recorded 87
#          correct and 29 incorrect in an incremental application to this
#          database.  He also showed that, by tuning EACH to this domain,
#          EACH was able to derive (non-incrementally) a set of 28
# ...

# %%
dataframe
df = dataframe.rename(columns={'11':'aliveatAux', '0':'still-alive','71':'age-at-heart-attack', '0.1':'pericardial-effusion', '0.260':'fractional-shortening', '9':'epss', '4.600':'lvdd', '14':'wall-motion-score', '1':'wall-motion-index', '1.1':'mult', 'name':'name', '1.2':'group', '0.2':'alive-at-1' })
#df = dataframe.rename(columns={'0':'still-alive'})
df
# Out:
#     aliveatAux  still-alive age-at-heart-attack  pericardial-effusion  \
# 0           19            0                  72                     0
# 1           16            0                  55                     0
# 2           57            0                  60                     0
# 3           19            1                  57                     0
# 4           26            0                  68                     0
# ..         ...          ...                 ...                   ...
# 125        7.5            1                  64                     0
# 126         41            0                  64                     0
# 127         36            0                  69                     0
# 128         22            0                  57                     0
# 129         20            0                  62                     0
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index  \
# ...

# %% [markdown]
# ## (c) According to that same information, is there any redundant or irrelevant attribute that you can remove? Remove them.
# Estas comlumnas no proporciona información útil para el análisis y pueden eliminarse del dataframe.
# * 'name': Esta columna parece contener solo un valor constante ("name")
# * 'group': Al igual que la columna 'name', parece contener solo un valor constante ("1")
# * 'alive-at-1': Esta columna contiene valores faltantes (NaN)
# * 'mult': Porque lo especifica dentro del contenido de la página web que no es necesario

# %%
df = df.drop(['name', 'group', 'alive-at-1', 'mult'], axis=1)
df
# Out:
#     aliveatAux  still-alive age-at-heart-attack  pericardial-effusion  \
# 0           19            0                  72                     0
# 1           16            0                  55                     0
# 2           57            0                  60                     0
# 3           19            1                  57                     0
# 4           26            0                  68                     0
# ..         ...          ...                 ...                   ...
# 125        7.5            1                  64                     0
# 126         41            0                  64                     0
# 127         36            0                  69                     0
# 128         22            0                  57                     0
# 129         20            0                  62                     0
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index
# ...

# %% [markdown]
# ## (d) Is there any data type change that you find useful? Perform it.
#
# *  'pericardial-effusion' podría ser convertida a tipo de dato booleano 0=sin líquido, 1=líquido.
# *  'still-alive' podría ser convertida a tipo de dato booleano 0 para fallecido y 1 para vivo.

# %%
df['still-alive'] = df['still-alive'].astype(bool)
df['pericardial-effusion'] = df['pericardial-effusion'].astype(bool)
df
# Out:
#     aliveatAux  still-alive age-at-heart-attack  pericardial-effusion  \
# 0           19        False                  72                 False
# 1           16        False                  55                 False
# 2           57        False                  60                 False
# 3           19         True                  57                 False
# 4           26        False                  68                 False
# ..         ...          ...                 ...                   ...
# 125        7.5         True                  64                 False
# 126         41        False                  64                 False
# 127         36        False                  69                 False
# 128         22        False                  57                 False
# 129         20        False                  62                 False
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index
# ...
